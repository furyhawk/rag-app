# %%
import pandas as pd

# %%
df = pd.read_csv("uparceladmin_faq.csv")

# %%
df
# Out:
#      id_faq                                           question  \
# 0        26     Is there any tracking available for my parcel?
# 1        58  Can I cancel the job after I have submitted th...
# 2        72  Can I cancel the delivery request after receiv...
# 3        73              What does the delivery price include?
# 4        74    Are there any tracking available for my parcel?
# ..      ...                                                ...
# 248     323                        如果我有待处理的即时支出要求，我可以要求另一笔支出吗？
# 249     324                                为什么我不能提取 200 新币的收入？
# 250     325                                    工作索赔会显示在代理钱包里吗？
# 251     326  What happens if my package is declared as over...
# 252     327  What happens if I am not around when delivery ...
#
#                                                 answer     faq_type  \
# 0    Yes, you will see the tracking number under yo...     customer
# 1    Yes, you can cancel the delivery request after...     customer
# ...

# %%
faq_df = df["question"] + df["answer"]

# %%
faq_df.to_csv("faq.csv", index=False)
